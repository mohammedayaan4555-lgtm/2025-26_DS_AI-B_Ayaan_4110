# %% [markdown]
# <a href="https://colab.research.google.com/github/mohammedayaan4555-lgtm/2025-26_DS_AI-B_Ayaan_4110/blob/main/22_test_of_hypothesisipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #22.Write a code to test for hypothesis,if test for Z is acceptd or rejected

# %%
import math
n=100
x=50
p_hat=x/n
SE=math.sqrt(p_hat*(1-p_hat)/n)
z=1.96
lower=p_hat-z*SE
upper=p_hat+z*SE
print("Sample proportion=",p_hat)
print("Confidence interval=",(lower,upper))
p0=0.50
z_test=(p_hat-p0)/math.sqrt(p0*(1-p0)/n)
print("Test Statistical:",z_test)
if abs(z_test)>1.96:
   print("Reject null hypothesis")
else:
     print("Accept null hypothesis")
# Out:
# Sample proportion= 0.5
# Confidence interval= (0.402, 0.598)
# Test Statistical: 0.0
# Accept null hypothesis
