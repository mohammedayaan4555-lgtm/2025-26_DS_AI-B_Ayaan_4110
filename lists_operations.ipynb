# %% [markdown]
# <a href="https://colab.research.google.com/github/mohammedayaan4555-lgtm/2025-26_DS_AI-B_Ayaan_4110/blob/main/lists_operations.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
lists=[10,20,30]
print(lists)
lists[0]
# Out:
# [10, 20, 30]
# 10

# %%
lists.append(40)
lists.pop()
print(lists)
lists.insert(60,80)
lists[1:3]
# Out:
# [80, 80, 70, 70, 40, 40, 40, 30, 20, 10, 80, 80, 80]
# [80, 70]

# %%
len(lists)
# Out:
# 10

# %%
lists.reverse()
lists
# Out:
# [80, 80, 70, 70, 40, 40, 40, 30, 20, 10]
