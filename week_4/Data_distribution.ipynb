# %% [markdown]
# <a href="https://colab.research.google.com/github/mohammedayaan4555-lgtm/2025-26_DS_AI-B_Ayaan_4110/blob/main/Data_distribution.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Data Distribution
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
normal_data = np.random.normal(loc=70, scale=5, size=1000)
right_skewed = np.random.exponential(scale=2, size=1000)
left_skewed = -np.random.exponential(scale=2, size=1000)
plt.hist(normal_data, bins=30)
plt.title("Normal Distribution")
plt.show()
plt.hist(right_skewed, bins=30)
plt.title("Right Skewed Distribution")
plt.show()
plt.hist(left_skewed, bins=30)
plt.title("Left Skewed Distribution")
plt.show()
print("Normal Data Mean:", np.mean(normal_data))
print("Normal Data Median:", np.median(normal_data))
print("Right Skewed Mean:", np.mean(right_skewed))
print("Right Skewed Median:", np.median(right_skewed))
print("Left Skewed Mean:", np.mean(left_skewed))
print("Left Skewed Median:", np.median(left_skewed))
# Out:
# Normal Data Mean: 69.97434980969426
# Normal Data Median: 70.14594203453689
# Right Skewed Mean: 2.1606054317960517
# Right Skewed Median: 1.4533053082491088
# Left Skewed Mean: -2.0693323217087563
# Left Skewed Median: -1.2836543981396633
