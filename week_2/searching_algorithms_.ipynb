# %% [markdown]
# <a href="https://colab.research.google.com/github/mohammedayaan4555-lgtm/2025-26_DS_AI-B_Ayaan_4110/blob/main/searching_algorithms_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Linear search
n = int(input("Enter a number of elements: "))
arr = []

for i in range(n):
    arr.append(int(input(f"Enter element{i+1}: ")))

key = int(input("enter element to search: "))

# linear search logic
found = False
for i in range(n):
    if arr[i] == key:
        print(f"Element {key} found at position: {i+1}")
        found = True
        break

if not found:
    print("Element not found")
# Out:
# Enter a number of elements: 4
# Enter element1: 3
# Enter element2: 2
# Enter element3: 1
# Enter element4: 4
# enter element to search: 1
# Element 1 found at position: 3

# %%
# binary search
n = int(input("enter number of elements: "))
arr = []
# input elements
for i in range(n):
    arr.append(int(input(f"Enter element {i+1}: ")))
# sorting the list first
arr.sort()
print("\nsorted list:", arr)
key = int(input("Enter element to search: "))
# Binary search logic
low = 0
high = n - 1
found = False
while low <= high:
    mid = (low + high) // 2
    if arr[mid] == key:
        print(f"element {key} found at position {mid + 1}")
        found = True
        break
    elif arr[mid] < key:
        low = mid + 1
    else:
        high = mid - 1
if not found:
    print("element not found")
# Out:
# enter number of elements: 4
# Enter element 1: 2
# Enter element 2: 4
# Enter element 3: 1
# Enter element 4: 5
#
# sorted list: [1, 2, 4, 5]
# Enter element to search: 4
# element 4 found at position 3
