# %% [markdown]
# <a href="https://colab.research.google.com/github/mohammedayaan4555-lgtm/2025-26_DS_AI-B_Ayaan_4110/blob/main/bubble_sort_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# bubble sort
n = int(input("Enter number of elements: "))
arr = []
# taking inout
for i in range(n):
    arr.append(int(input(f"Enter element{i+1}: ")))
print("original array:", arr)
# Bubble sort logic
for i in range(n - 1):
    for j in range(n - 1 - i):
        if arr[j] > arr[j + 1]:
            # swapp
            arr[j], arr[j + 1] = arr[j + 1], arr[j]
print("sorted array:", arr)
# Out:
# Enter number of elements: 4
# Enter element1: 9
# Enter element2: 3
# Enter element3: 6
# Enter element4: 3
# original array: [9, 3, 6, 3]
# sorted array: [3, 3, 6, 9]
